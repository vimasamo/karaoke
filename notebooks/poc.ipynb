# %%
import json
from youtubesearchpython import *

# %%
param = 'abrazame muy fuerte'

videosSearch = VideosSearch(f'"karaoke"+"{param}"', limit = 40)
resultados = videosSearch.result()
resultados = [[i['title'],i['link'],i['richThumbnail']] for i in resultados['result']]
res = []
for i in resultados:
    if i[2] == None:
        pass
    else:
        res.append(i)
resultados = res[0:12]
del res
for i in resultados:
    i[2] = i[2]['url']

# %%
for j in range(0,len(resultados),3):
    lst = resultados[j:j+3]
    print(lst)
# Out:
# [['Juan Gabriel Abrazame Muy Fuerte Karaoke', 'https://www.youtube.com/watch?v=6dnhpjmjNmU', 'https://i.ytimg.com/an_webp/6dnhpjmjNmU/mqdefault_6s.webp?du=3000&sqp=CLi8rZ0G&rs=AOn4CLAWa8gu7La9bBQ8w2EPVHMzz-TQCA'], ['Abrázame Muy Fuerte - Multikaraoke -  Juan Michel', 'https://www.youtube.com/watch?v=bAfUc91Hr3g', 'https://i.ytimg.com/an_webp/bAfUc91Hr3g/mqdefault_6s.webp?du=3000&sqp=COjdrZ0G&rs=AOn4CLB0P2PEdB1okr1e7vguyKiYHMs4tQ'], ['Abrázame Muy Fuerte - Orquesta Melodía al estilo de Juan Gabriel - Karaoke', 'https://www.youtube.com/watch?v=Z5kf2V_IrTA', 'https://i.ytimg.com/an_webp/Z5kf2V_IrTA/mqdefault_6s.webp?du=3000&sqp=CMDWrZ0G&rs=AOn4CLBj0dMkmIdWQEHUiFrnzSVEiHiYcw']]
# ...

# %%
fetcher = StreamURLFetcher()
video = Video.get("https://www.youtube.com/watch?v=aqz-KE-bpKQ")
url = fetcher.getAll(video)

# %%
url
# Out:
# {'streams': [{'itag': 17,
#    'url': 'https://rr3---sn-0opoxu-9gve.googlevideo.com/videoplayback?expire=1672293586&ei=ctisY8HgKY_zigSZ-K2YCw&ip=187.145.70.182&id=o-ACQMPQij1wEMPLYeDZE6i6ZFXBgLfVMPqxR9O_KCQYlT&itag=17&source=youtube&requiressl=yes&mh=aP&mm=31%2C29&mn=sn-0opoxu-9gve%2Csn-9gv7zn7e&ms=au%2Crdu&mv=m&mvi=3&pl=21&initcwndbps=716250&vprv=1&mime=video%2F3gpp&gir=yes&clen=6325118&dur=634.694&lmt=1662343583284535&mt=1672271593&fvip=3&fexp=24001373%2C24007246&c=ANDROID&txp=5532434&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRAIgVHc2yYl5_eZr6HfDd6iJtsLhfr1lByDikfpRWZIAxPUCIHxacdS4qlSiHK1Dc4BL0_-kie6CSQ-0I0czqQrDgltN&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRQIhAN6GvwG5FB2KOvA_Lt5hqyH2fpwfF_8DWRdeo-LF_6JAAiBqDckN-iIP7dZuipDfNKNoHl1b5jdjxAXVxfxM1g0UiQ%3D%3D',
#    'mimeType': 'video/3gpp; codecs="mp4v.20.3, mp4a.40.2"',
#    'bitrate': 79745,
#    'width': 176,
#    'height': 144,
# ...
